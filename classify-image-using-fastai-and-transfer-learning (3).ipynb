# %%
import warnings
warnings.filterwarnings('ignore')
from fastai.vision.all import *

# %%
path = Path(r'C:\Users\kavit\Downloads\clean messy room dataset\images')

# %%
data = ImageDataLoaders.from_folder(
    path, 
    train='train',
    valid='val',
    test='test',
    item_tfms=Resize(224),
)

data.show_batch(max_n=9, figsize=(7,6))

# %%
learn = cnn_learner(data, resnet34, metrics=accuracy)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.914821</td>
#       <td>0.451736</td>
#       <td>0.900000</td>
#       <td>00:33</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(bob)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('messy', tensor(1), tensor([0.2717, 0.7283]))

# %%
from fastai import learner
learn.save("bablu_best")
# Out:
# Path('C:/Users/kavit/Downloads/clean messy room dataset/images/models/bablu_best.pth')

# %%
path = Path(r'C:\Users\kavit\Downloads\clean messy room dataset\images')
data = ImageDataLoaders.from_folder(
    path, 
    train='train',
    valid='val',
    test='test',
    item_tfms=Resize(224),
)
data.show_batch(max_n=9, figsize=(7,6))
learn = cnn_learner(data, resnet34, metrics=accuracy)
bob = learn.load("bablu_best")

# %%
bob.predict(r"C:\Users\kavit\Downloads\clean messy room dataset\images\test\10.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('messy', tensor(1), tensor([0.0823, 0.9177]))
